# %% [markdown]
# # PLANTILLA MODELIZACIÓN PARA REGRESIÓN

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# **IMPORTANTE**: Esta plantilla está diseñada para una visión de máximos utilizando el framework de The Ultimate Algo Machine. Si tienes problemas de memoria o rendimiento recuerda reducir el problema mediante:
#
# * Muestreo
# * Balanceo undersampling
# * Reducir el número de algoritmos a testar
# * Reducir el número de parámetros a testar
# * Usar random search y especificar un n_iter adecuado

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.pipeline import Pipeline

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

from sklearn.metrics import mean_absolute_percentage_error

#Autocompletar rápido
# %config IPCompleter.greedy=True

#Desactivar la notación científica
pd.options.display.float_format = '{:.2f}'.format

#Desactivar los warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/isaac/Google Drive/DS4B/CursoMachineLearningPython/03_MACHINE_LEARNING/08_CASOS/00_PROYECTO1'

# %% [markdown]
# Nombres de los ficheros de datos.

# %%
nombre_x = 'x_final.pickle'
nombre_y = 'y_final.pickle'

# %% [markdown]
# Cargar los datos.

# %%
x = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_x)
y = pd.read_pickle(ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_y)

# %% [markdown]
# ## MODELIZAR

# %% [markdown]
# ### Reservar el dataset de validacion

# %%
train_x,val_x,train_y,val_y = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ### Crear el pipe y el diccionario de algorimos, parámetros y valores a testar

# %% [markdown]
# Modificar para dejar solo los algoritmos que se quieran testar.
#
# Modificar los parámetros.

# %%
pipe = Pipeline([('algoritmo',RandomForestRegressor())])

grid = [{'algoritmo': [LinearRegression()],
         'algoritmo__n_jobs': [-1]},
        
        {'algoritmo': [RandomForestRegressor()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__max_depth': [5,10,15],
         'algoritmo__n_estimators': [50,100,200]},
        
        {'algoritmo': [XGBRegressor()],
         'algoritmo__n_jobs': [-1],
         'algoritmo__learning_rate': [0.01,0.025,0.05,0.1],
         'algoritmo__max_depth': [5,10,20],
         'algoritmo__reg_alpha': [0,0.1,0.5,1],
         'algoritmo__reg_lambda': [0.01,0.1,1],
         'algoritmo__n_estimators': [100,500,1000]},
        
        {'algoritmo': [HistGradientBoostingRegressor()],
         'algoritmo__learning_rate': [0.01,0.025,0.05,0.1],
         'algoritmo__max_iter': [50,100,200],
         'algoritmo__max_depth': [5,10,20],
         'algoritmo__min_samples_leaf': [500],
         'algoritmo__scoring': ['neg_mean_absolute_percentage_error'],
         'algoritmo__l2_regularization': [0,0.25,0.5,0.75,1]}
       ]

# %% [markdown]
# ### Optimizar los hiper parámetros

# %% [markdown]
# Elegir si se quiere usar grid search o random search.
#
# Comentar la opción que no se vaya a usar.

# %% [markdown]
# ####  Con grid search

# %%
# grid_search = GridSearchCV(estimator= pipe, 
#                            param_grid = grid, 
#                            cv = 3, 
#                            scoring = 'neg_mean_absolute_percentage_error',
#                            verbose = 0,
#                            n_jobs = -1)

# modelo = grid_search.fit(train_x,train_y)

# pd.DataFrame(grid_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0             0.02          0.00             0.00            0.00
# 352           3.97          0.16             0.01            0.00
# 364           4.50          0.18             0.01            0.00
# 360           7.80          0.13             0.01            0.00
# 348           4.18          0.13             0.01            0.00
# ..             ...           ...              ...             ...
# 301           4.57          0.11             0.01            0.00
# 313           8.24          0.12             0.01            0.00
# 325          11.82          0.59             0.01            0.00
# 217          17.26          0.41             0.01            0.00
# 205          12.85          0.98             0.01            0.00
#
#                                        param_algoritmo  \
# 0                          LinearRegression(n_jobs=-1)
# 352  XGBRegressor(base_score=None, booster=None, co...
# 364  XGBRegressor(base_score=None, booster=None, co...
# 360  XGBRegressor(base_score=None, booster=None, co...
# 348  XGBRegressor(base_score=None, booster=None, co...
# ..                                                 ...
# 301  XGBRegressor(base_score=None, booster=None, co...
# 313  XGBRegressor(base_score=None, booster=None, co...
# 325  XGBRegressor(base_score=None, booster=None, co...
# 217  XGBRegressor(base_score=None, booster=None, co...
# 205  XGBRegressor(base_score=None, booster=None, co...
#
#     param_algoritmo__n_jobs param_algoritmo__max_depth  \
# 0                        -1                        NaN
# 352                      -1                          5
# 364                      -1                          5
# 360                      -1                          5
# 348                      -1                          5
# ..                      ...                        ...
# 301                      -1                         20
# 313                      -1                         20
# 325                      -1                         20
# 217                      -1                         20
# 205                      -1                         20
#
#     param_algoritmo__n_estimators param_algoritmo__learning_rate  \
# 0                             NaN                            NaN
# 352                           500                           0.10
# 364                          1000                           0.10
# 360                          1000                           0.10
# 348                           500                           0.10
# ..                            ...                            ...
# 301                           100                           0.05
# 313                           500                           0.05
# 325                          1000                           0.05
# 217                          1000                           0.03
# 205                           500                           0.03
#
#     param_algoritmo__reg_alpha  ... param_algoritmo__max_iter  \
# 0                          NaN  ...                       NaN
# 352                       0.50  ...                       NaN
# 364                       0.50  ...                       NaN
# 360                          0  ...                       NaN
# 348                          0  ...                       NaN
# ..                         ...  ...                       ...
# 301                       0.10  ...                       NaN
# 313                       0.10  ...                       NaN
# 325                       0.10  ...                       NaN
# 217                       0.10  ...                       NaN
# 205                       0.10  ...                       NaN
#
#     param_algoritmo__min_samples_leaf param_algoritmo__scoring  \
# 0                                 NaN                      NaN
# 352                               NaN                      NaN
# 364                               NaN                      NaN
# 360                               NaN                      NaN
# 348                               NaN                      NaN
# ..                                ...                      ...
# 301                               NaN                      NaN
# 313                               NaN                      NaN
# 325                               NaN                      NaN
# 217                               NaN                      NaN
# 205                               NaN                      NaN
#
#                                                 params split0_test_score  \
# 0    {'algoritmo': LinearRegression(n_jobs=-1), 'al...             -0.24
# 352  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.52
# 364  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.52
# 360  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.57
# 348  {'algoritmo': XGBRegressor(base_score=None, bo...             -0.57
# ..                                                 ...               ...
# 301  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.72
# 313  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.73
# 325  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.73
# 217  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.85
# 205  {'algoritmo': XGBRegressor(base_score=None, bo...             -3.85
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0               -0.14              -0.24            -0.21            0.05
# 352             -0.70              -1.70            -0.97            0.52
# 364             -0.70              -1.70            -0.97            0.52
# 360             -0.74              -1.61            -0.97            0.46
# 348             -0.74              -1.61            -0.97            0.46
# ..                ...                ...              ...             ...
# 301             -1.70              -2.71            -2.71            0.82
# 313             -1.71              -2.72            -2.72            0.82
# 325             -1.71              -2.72            -2.72            0.82
# 217             -1.70              -2.72            -2.76            0.88
# 205             -1.70              -2.72            -2.76            0.88
#
#      rank_test_score
# 0                  1
# 352                2
# 364                2
# 360                4
# 348                5
# ..               ...
# 301              618
# 313              619
# 325              619
# 217              621
# 205              622
#
# [622 rows x 22 columns]

# %% [markdown]
# ####  Con random search

# %%
random_search = RandomizedSearchCV(estimator = pipe,
                                   param_distributions = grid, 
                                   n_iter = 25, 
                                   cv = 3, 
                                   scoring = 'neg_mean_absolute_percentage_error', 
                                   verbose = 0,
                                   n_jobs = -1)

modelo = random_search.fit(train_x,train_y)

pd.DataFrame(random_search.cv_results_).sort_values(by = 'rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 15           3.22          0.08             0.01            0.00
# 2            4.53          0.15             0.01            0.00
# 24           2.75          0.18             0.01            0.00
# 8            3.18          0.15             0.01            0.00
# 0            0.72          0.04             0.01            0.00
# 6            0.57          0.00             0.01            0.00
# 5            3.15          0.04             0.01            0.00
# 17           0.63          0.02             0.01            0.00
# 22           0.27          0.03             0.07            0.00
# 19           0.24          0.03             0.05            0.00
# 13           0.13          0.00             0.03            0.00
# 14           0.12          0.00             0.03            0.00
# 3            0.03          0.00             0.00            0.00
# 11           0.29          0.03             0.08            0.05
# 12           0.10          0.01             0.02            0.00
# 23           0.83          0.12             0.01            0.00
# 18           1.82          0.02             0.01            0.00
# 20           4.94          0.08             0.01            0.00
# 4            1.85          0.04             0.01            0.00
# 9           15.37          0.07             0.01            0.00
# 16           1.57          0.06             0.01            0.00
# 10          17.45          0.14             0.01            0.00
# 7            2.39          0.08             0.01            0.00
# 21           3.06          0.06             0.01            0.00
# 1            7.32          0.20             0.01            0.00
#
#    param_algoritmo__reg_lambda param_algoritmo__reg_alpha  \
# 15                           1                          1
# 2                         0.01                       0.10
# 24                           1                          1
# 8                         0.01                          0
# 0                            1                       0.50
# 6                            1                          0
# 5                         0.10                          1
# 17                        0.01                       0.10
# 22                         NaN                        NaN
# 19                         NaN                        NaN
# 13                         NaN                        NaN
# 14                         NaN                        NaN
# 3                          NaN                        NaN
# 11                         NaN                        NaN
# 12                         NaN                        NaN
# 23                        0.10                       0.10
# 18                        0.10                       0.50
# 20                           1                       0.50
# 4                         0.01                          0
# 9                         0.10                          1
# 16                        0.10                          1
# 10                        0.10                       0.50
# 7                         0.10                       0.10
# 21                        0.10                          0
# 1                         0.01                       0.10
#
#    param_algoritmo__n_jobs param_algoritmo__n_estimators  \
# 15                      -1                          1000
# 2                       -1                          1000
# 24                      -1                           500
# 8                       -1                           500
# 0                       -1                           100
# 6                       -1                           100
# 5                       -1                           500
# 17                      -1                           100
# 22                     NaN                           NaN
# 19                     NaN                           NaN
# 13                     NaN                           NaN
# 14                     NaN                           NaN
# 3                      NaN                           NaN
# 11                     NaN                           NaN
# 12                     NaN                           NaN
# 23                      -1                           100
# 18                      -1                           100
# 20                      -1                          1000
# 4                       -1                           100
# 9                       -1                          1000
# 16                      -1                           100
# 10                      -1                          1000
# 7                       -1                           100
# 21                      -1                           500
# 1                       -1                           500
#
#    param_algoritmo__max_depth param_algoritmo__learning_rate  ...  \
# 15                          5                           0.10  ...
# 2                           5                           0.10  ...
# 24                          5                           0.05  ...
# 8                           5                           0.03  ...
# 0                           5                           0.05  ...
# 6                           5                           0.05  ...
# 5                           5                           0.01  ...
# 17                          5                           0.05  ...
# 22                          5                           0.03  ...
# 19                         10                           0.05  ...
# 13                          5                           0.03  ...
# 14                         10                           0.10  ...
# 3                           5                           0.10  ...
# 11                          5                           0.03  ...
# 12                          5                           0.03  ...
# 23                          5                           0.03  ...
# 18                         10                           0.01  ...
# 20                         20                           0.10  ...
# 4                          10                           0.05  ...
# 9                          10                           0.01  ...
# 16                         20                           0.10  ...
# 10                         20                           0.01  ...
# 7                          20                           0.10  ...
# 21                         20                           0.10  ...
# 1                          20                           0.05  ...
#
#    param_algoritmo__min_samples_leaf param_algoritmo__max_iter  \
# 15                               NaN                       NaN
# 2                                NaN                       NaN
# 24                               NaN                       NaN
# 8                                NaN                       NaN
# 0                                NaN                       NaN
# 6                                NaN                       NaN
# 5                                NaN                       NaN
# 17                               NaN                       NaN
# 22                               500                       200
# 19                               500                       200
# 13                               500                       100
# 14                               500                       100
# 3                                500                        50
# 11                               500                       100
# 12                               500                        50
# 23                               NaN                       NaN
# 18                               NaN                       NaN
# 20                               NaN                       NaN
# 4                                NaN                       NaN
# 9                                NaN                       NaN
# 16                               NaN                       NaN
# 10                               NaN                       NaN
# 7                                NaN                       NaN
# 21                               NaN                       NaN
# 1                                NaN                       NaN
#
#    param_algoritmo__l2_regularization  \
# 15                                NaN
# 2                                 NaN
# 24                                NaN
# 8                                 NaN
# 0                                 NaN
# 6                                 NaN
# 5                                 NaN
# 17                                NaN
# 22                               0.25
# 19                               0.25
# 13                               0.25
# 14                                  1
# 3                                0.25
# 11                               0.75
# 12                                  1
# 23                                NaN
# 18                                NaN
# 20                                NaN
# 4                                 NaN
# 9                                 NaN
# 16                                NaN
# 10                                NaN
# 7                                 NaN
# 21                                NaN
# 1                                 NaN
#
#                                                params split0_test_score  \
# 15  {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -0.61
# 2   {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -0.62
# 24  {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -0.57
# 8   {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -0.77
# 0   {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -0.66
# 6   {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -0.72
# 5   {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -0.86
# 17  {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -0.87
# 22  {'algoritmo__scoring': 'neg_mean_absolute_perc...             -1.32
# 19  {'algoritmo__scoring': 'neg_mean_absolute_perc...             -1.32
# 13  {'algoritmo__scoring': 'neg_mean_absolute_perc...             -1.32
# 14  {'algoritmo__scoring': 'neg_mean_absolute_perc...             -1.32
# 3   {'algoritmo__scoring': 'neg_mean_absolute_perc...             -1.32
# 11  {'algoritmo__scoring': 'neg_mean_absolute_perc...             -1.32
# 12  {'algoritmo__scoring': 'neg_mean_absolute_perc...             -1.32
# 23  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -1.01
# 18  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -1.96
# 20  {'algoritmo__reg_lambda': 1, 'algoritmo__reg_a...             -2.55
# 4   {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -2.31
# 9   {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -2.61
# 16  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -2.56
# 10  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -2.91
# 7   {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.13
# 21  {'algoritmo__reg_lambda': 0.1, 'algoritmo__reg...             -3.18
# 1   {'algoritmo__reg_lambda': 0.01, 'algoritmo__re...             -3.73
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 15             -0.78              -1.61            -1.00            0.44
# 2              -0.75              -1.67            -1.01            0.47
# 24             -0.76              -1.75            -1.03            0.52
# 8              -0.69              -1.68            -1.05            0.45
# 0              -0.79              -1.97            -1.14            0.59
# 6              -0.80              -1.98            -1.17            0.58
# 5              -0.74              -1.92            -1.18            0.53
# 17             -0.77              -1.97            -1.20            0.55
# 22             -1.00              -1.34            -1.22            0.16
# 19             -1.00              -1.34            -1.22            0.16
# 13             -1.00              -1.34            -1.22            0.16
# 14             -1.00              -1.34            -1.22            0.16
# 3              -1.00              -1.34            -1.22            0.16
# 11             -1.00              -1.34            -1.22            0.16
# 12             -1.00              -1.34            -1.22            0.16
# 23             -0.92              -2.03            -1.32            0.50
# 18             -1.03              -1.69            -1.56            0.39
# 20             -1.00              -2.24            -1.93            0.67
# 4              -1.28              -2.40            -2.00            0.51
# 9              -1.25              -2.28            -2.05            0.58
# 16             -1.33              -2.56            -2.15            0.58
# 10             -1.35              -2.75            -2.34            0.70
# 7              -1.34              -2.73            -2.40            0.77
# 21             -1.39              -2.85            -2.47            0.78
# 1              -1.71              -2.72            -2.72            0.82
#
#     rank_test_score
# 15                1
# 2                 2
# 24                3
# 8                 4
# 0                 5
# 6                 6
# 5                 7
# 17                8
# 22                9
# 19                9
# 13                9
# 14                9
# 3                 9
# 11                9
# 12                9
# 23               16
# 18               17
# 20               18
# 4                19
# 9                20
# 16               21
# 10               22
# 7                23
# 21               24
# 1                25
#
# [25 rows x 22 columns]

# %% [markdown]
# ## EVALUAR

# %% [markdown]
# ### Predecir sobre validación

# %%
pred = modelo.best_estimator_.predict(val_x)

# %% [markdown]
# ### Evaluar sobre validación

# %%
mean_absolute_percentage_error(val_y, pred)
# Out:
# 0.9676047896698653

# %% [markdown]
# ### Examinar el mejor modelo

# %%
modelo.best_estimator_
# Out:
# Pipeline(steps=[('algoritmo',
#                  XGBRegressor(base_score=0.5, booster='gbtree',
#                               colsample_bylevel=1, colsample_bynode=1,
#                               colsample_bytree=1, enable_categorical=False,
#                               gamma=0, gpu_id=-1, importance_type=None,
#                               interaction_constraints='', learning_rate=0.1,
#                               max_delta_step=0, max_depth=5, min_child_weight=1,
#                               missing=nan, monotone_constraints='()',
#                               n_estimators=1000, n_jobs=-1, num_parallel_tree=1,
#                               predictor='auto', random_state=0, reg_alpha=1,
#                               reg_lambda=1, scale_pos_weight=1, subsample=1,
#                               tree_method='exact', validate_parameters=1,
#                               verbosity=None))])
