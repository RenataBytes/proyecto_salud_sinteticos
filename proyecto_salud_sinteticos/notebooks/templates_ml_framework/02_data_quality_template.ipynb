# %% [markdown]
# # PLANTILLA CALIDAD DE DATOS

# %% [markdown]
# **IMPORTANTE**: Recuerda hacer una copia de esta plantilla para no machacar la original.

# %% [markdown]
# ## IMPORTAR PAQUETES

# %%
import numpy as np
import pandas as pd
from janitor import clean_names

#Automcompletar rápido
# %config IPCompleter.greedy=True

# %% [markdown]
# ## IMPORTAR LOS DATOS

# %% [markdown]
# Sustituir la ruta del proyecto.

# %%
ruta_proyecto = 'C:/Users/renata/Google Drive/datosciencia/00_PROYECTO1'

# %% [markdown]
# Sustituir el nombre_fichero_datos.

# %%
nombre_fichero_datos = 'muestra.csv'

# %% [markdown]
# Cargar los datos.

# %%
ruta_completa = ruta_proyecto + '/02_Datos/03_Trabajo/' + nombre_fichero_datos

df = pd.read_csv(ruta_completa,index_col=0)
df
# Out:
#        Edad     Trabajo Estado Civil             Fomación   Impago  \
# 27151  67.0     retired      married             basic.4y       no
# 24641  37.0      admin.       single          high.school       no
# 19644  28.0  management      married          high.school  unknown
# 3126   40.0  technician      married  professional.course  unknown
# 15803  57.0      admin.      married                  NaN       no
# ...     ...         ...          ...                  ...      ...
# 33181   NaN    services      married             basic.9y       no
# 5355   45.0      admin.     divorced  professional.course       no
# 16908  27.0     unknown       single          high.school  unknown
# 38008  53.0  technician      married  professional.course       no
# 36761  44.0    services      married          high.school       no
#
#       Prestamo hipotecario Prestamo Personal Canal de contacto  Mes  \
# 27151                   no                no         telephone  nov
# 24641                   no                no          cellular  apr
# 19644                   no                no         telephone  jun
# 3126                   yes                no         telephone  may
# 15803                  yes                no          cellular  jul
# ...                    ...               ...               ...  ...
# 33181                  yes                no         telephone  may
# 5355                    no               yes          cellular  may
# 16908                  yes               yes          cellular  may
# 38008                   no               yes          cellular  jul
# 36761                  yes               yes         telephone  may
#
#       Dia de la semana  num contactos esta campaña  num días último contacto  \
# 27151              NaN                           4                       999
# 24641              NaN                           1                       999
# 19644              NaN                           6                       999
# 3126               NaN                           1                       999
# 15803              NaN                           7                       999
# ...                ...                         ...                       ...
# 33181              NaN                           3                       999
# 5355               fri                           1                       999
# 16908              NaN                           1                       999
# 38008              NaN                          11                       999
# 36761              NaN                           1                       999
#
#        num contactos otras campañas resultado campaña anterior  \
# 27151                             1                    failure
# 24641                             1                    failure
# 19644                             0                nonexistent
# 3126                              0                nonexistent
# 15803                             0                nonexistent
# ...                             ...                        ...
# 33181                             0                nonexistent
# 5355                              1                    failure
# 16908                             1                    failure
# 38008                             0                nonexistent
# 36761                             0                nonexistent
#
#        variación tasa empleo  euribor3m  contrata_fondos
# 27151                    -34        718                0
# 24641                    -18        141                0
# 19644                     14       4961                0
# 3126                      11       4857                0
# 15803                     14       4961                0
# ...                      ...        ...              ...
# 33181                     11       4857                0
# 5355                     -18       1313                0
# 16908                    -18       1299                0
# 38008                     14       4961                0
# 36761                     11       4857                0
#
# [20000 rows x 17 columns]

# %% [markdown]
# ## CORRECCIÓN DE NOMBRES DE VARIABLES

# %% [markdown]
# ### Corrección automática

# %%
df = clean_names(df)
df
# Out:
#        edad     trabajo estado_civil             fomacion   impago  \
# 27151  67.0     retired      married             basic.4y       no
# 24641  37.0      admin.       single          high.school       no
# 19644  28.0  management      married          high.school  unknown
# 3126   40.0  technician      married  professional.course  unknown
# 15803  57.0      admin.      married                  NaN       no
# ...     ...         ...          ...                  ...      ...
# 33181   NaN    services      married             basic.9y       no
# 5355   45.0      admin.     divorced  professional.course       no
# 16908  27.0     unknown       single          high.school  unknown
# 38008  53.0  technician      married  professional.course       no
# 36761  44.0    services      married          high.school       no
#
#       prestamo_hipotecario prestamo_personal canal_de_contacto  mes  \
# 27151                   no                no         telephone  nov
# 24641                   no                no          cellular  apr
# 19644                   no                no         telephone  jun
# 3126                   yes                no         telephone  may
# 15803                  yes                no          cellular  jul
# ...                    ...               ...               ...  ...
# 33181                  yes                no         telephone  may
# 5355                    no               yes          cellular  may
# 16908                  yes               yes          cellular  may
# 38008                   no               yes          cellular  jul
# 36761                  yes               yes         telephone  may
#
#       dia_de_la_semana  num_contactos_esta_campana  num_dias_ultimo_contacto  \
# 27151              NaN                           4                       999
# 24641              NaN                           1                       999
# 19644              NaN                           6                       999
# 3126               NaN                           1                       999
# 15803              NaN                           7                       999
# ...                ...                         ...                       ...
# 33181              NaN                           3                       999
# 5355               fri                           1                       999
# 16908              NaN                           1                       999
# 38008              NaN                          11                       999
# 36761              NaN                           1                       999
#
#        num_contactos_otras_campanas resultado_campana_anterior  \
# 27151                             1                    failure
# 24641                             1                    failure
# 19644                             0                nonexistent
# 3126                              0                nonexistent
# 15803                             0                nonexistent
# ...                             ...                        ...
# 33181                             0                nonexistent
# 5355                              1                    failure
# 16908                             1                    failure
# 38008                             0                nonexistent
# 36761                             0                nonexistent
#
#        variacion_tasa_empleo  euribor3m  contrata_fondos
# 27151                    -34        718                0
# 24641                    -18        141                0
# 19644                     14       4961                0
# 3126                      11       4857                0
# 15803                     14       4961                0
# ...                      ...        ...              ...
# 33181                     11       4857                0
# 5355                     -18       1313                0
# 16908                    -18       1299                0
# 38008                     14       4961                0
# 36761                     11       4857                0
#
# [20000 rows x 17 columns]

# %% [markdown]
# ### Corrección manual

# %%
df.rename(columns = {'fomacion':'formacion',
                     'prestamo_hipotecario':'hipoteca',
                     'prestamo_personal':'consumo'}, inplace=True)
df
# Out:
#        edad     trabajo estado_civil            formacion   impago hipoteca  \
# 27151  67.0     retired      married             basic.4y       no       no
# 24641  37.0      admin.       single          high.school       no       no
# 19644  28.0  management      married          high.school  unknown       no
# 3126   40.0  technician      married  professional.course  unknown      yes
# 15803  57.0      admin.      married                  NaN       no      yes
# ...     ...         ...          ...                  ...      ...      ...
# 33181   NaN    services      married             basic.9y       no      yes
# 5355   45.0      admin.     divorced  professional.course       no       no
# 16908  27.0     unknown       single          high.school  unknown      yes
# 38008  53.0  technician      married  professional.course       no       no
# 36761  44.0    services      married          high.school       no      yes
#
#       consumo canal_de_contacto  mes dia_de_la_semana  \
# 27151      no         telephone  nov              NaN
# 24641      no          cellular  apr              NaN
# 19644      no         telephone  jun              NaN
# 3126       no         telephone  may              NaN
# 15803      no          cellular  jul              NaN
# ...       ...               ...  ...              ...
# 33181      no         telephone  may              NaN
# 5355      yes          cellular  may              fri
# 16908     yes          cellular  may              NaN
# 38008     yes          cellular  jul              NaN
# 36761     yes         telephone  may              NaN
#
#        num_contactos_esta_campana  num_dias_ultimo_contacto  \
# 27151                           4                       999
# 24641                           1                       999
# 19644                           6                       999
# 3126                            1                       999
# 15803                           7                       999
# ...                           ...                       ...
# 33181                           3                       999
# 5355                            1                       999
# 16908                           1                       999
# 38008                          11                       999
# 36761                           1                       999
#
#        num_contactos_otras_campanas resultado_campana_anterior  \
# 27151                             1                    failure
# 24641                             1                    failure
# 19644                             0                nonexistent
# 3126                              0                nonexistent
# 15803                             0                nonexistent
# ...                             ...                        ...
# 33181                             0                nonexistent
# 5355                              1                    failure
# 16908                             1                    failure
# 38008                             0                nonexistent
# 36761                             0                nonexistent
#
#        variacion_tasa_empleo  euribor3m  contrata_fondos
# 27151                    -34        718                0
# 24641                    -18        141                0
# 19644                     14       4961                0
# 3126                      11       4857                0
# 15803                     14       4961                0
# ...                      ...        ...              ...
# 33181                     11       4857                0
# 5355                     -18       1313                0
# 16908                    -18       1299                0
# 38008                     14       4961                0
# 36761                     11       4857                0
#
# [20000 rows x 17 columns]

# %% [markdown]
# ## VISIÓN GENERAL

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 27151 to 36761
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   edad                          18643 non-null  float64
#  1   trabajo                       20000 non-null  object
#  2   estado_civil                  20000 non-null  object
#  3   formacion                     17568 non-null  object
#  4   impago                        20000 non-null  object
#  5   hipoteca                      20000 non-null  object
#  6   consumo                       20000 non-null  object
#  7   canal_de_contacto             20000 non-null  object
#  8   mes                           20000 non-null  object
#  9   dia_de_la_semana              1012 non-null   object
#  10  num_contactos_esta_campana    20000 non-null  int64
#  11  num_dias_ultimo_contacto      20000 non-null  int64
#  12  num_contactos_otras_campanas  20000 non-null  int64
#  13  resultado_campana_anterior    20000 non-null  object
#  14  variacion_tasa_empleo         20000 non-null  int64
#  15  euribor3m                     20000 non-null  int64
#  16  contrata_fondos               20000 non-null  int64
# dtypes: float64(1), int64(6), object(10)
# memory usage: 2.7+ MB

# %% [markdown]
# ## TIPOS DE DATOS

# %% [markdown]
# ### Identificación

# %%
df.dtypes
# Out:
# edad                            float64
# trabajo                          object
# estado_civil                     object
# formacion                        object
# impago                           object
# hipoteca                         object
# consumo                          object
# canal_de_contacto                object
# mes                              object
# dia_de_la_semana                 object
# num_contactos_esta_campana        int64
# num_dias_ultimo_contacto          int64
# num_contactos_otras_campanas      int64
# resultado_campana_anterior       object
# variacion_tasa_empleo             int64
# euribor3m                         int64
# contrata_fondos                   int64
# dtype: object

# %% [markdown]
# ### Corrección

# %%
df = df.astype({'edad':'Int64',
           'euribor3m': 'float'})

df.dtypes
# Out:
# edad                              Int64
# trabajo                          object
# estado_civil                     object
# formacion                        object
# impago                           object
# hipoteca                         object
# consumo                          object
# canal_de_contacto                object
# mes                              object
# dia_de_la_semana                 object
# num_contactos_esta_campana        int64
# num_dias_ultimo_contacto          int64
# num_contactos_otras_campanas      int64
# resultado_campana_anterior       object
# variacion_tasa_empleo             int64
# euribor3m                       float64
# contrata_fondos                   int64
# dtype: object

# %% [markdown]
# ## VALORES ÚNICOS

# %% [markdown]
# ### Identificación

# %%
df.nunique().sort_values()
# Out:
# contrata_fondos                   2
# canal_de_contacto                 2
# impago                            3
# hipoteca                          3
# consumo                           3
# resultado_campana_anterior        3
# estado_civil                      4
# dia_de_la_semana                  5
# num_contactos_otras_campanas      7
# formacion                         8
# variacion_tasa_empleo            10
# mes                              10
# trabajo                          12
# num_dias_ultimo_contacto         24
# num_contactos_esta_campana       37
# edad                             73
# euribor3m                       300
# dtype: int64

# %% [markdown]
# ### Corrección

# %%
df.drop(columns = 'canal_de_contacto', inplace = True)

# %% [markdown]
# ## DUPLICADOS

# %% [markdown]
# ### Identificación

# %%
df.duplicated().sum()
# Out:
# 404

# %% [markdown]
# ### Corrección

# %%
df.drop_duplicates(inplace = True)

# %% [markdown]
# ## SEPARAR NUMÉRICAS Y CATEGÓRICAS

# %% [markdown]
# ### Categóricas

# %%
cat = df.select_dtypes(exclude = 'number').copy()

# %% [markdown]
# ### Numéricas

# %%
num = df.select_dtypes(include='number').copy()

# %% [markdown]
# ## GESTIÓN DE CATEGÓRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
cat.isna().sum().sort_values(ascending = False)
# Out:
# dia_de_la_semana              18585
# formacion                      2416
# trabajo                           0
# estado_civil                      0
# impago                            0
# hipoteca                          0
# consumo                           0
# mes                               0
# resultado_campana_anterior        0
# dtype: int64

# %% [markdown]
# #### Corrección

# %% [markdown]
# ##### Eliminar la variable

# %%
cat.drop(columns = 'dia_de_la_semana',inplace = True)

# %% [markdown]
# ##### Eliminar registros

# %% [markdown]
# *Cuidado: Si se eliminan registros hay que eliminarlos tanto de cat como de num*

# %%
criterio = 3
cat.dropna(thresh=criterio, inplace=True)
num.dropna(thresh=criterio, inplace=True)

# %% [markdown]
# ##### Imputar por un valor

# %% [markdown]
# ###### Variables a imputar

# %%
#var_imputar_valor = ['resultado_campana_anterior','formacion']

# %% [markdown]
# ###### Valor por el que imputar

# %%
valor = 'NULO'

# %% [markdown]
# ###### Imputar

# %%
# cat[var_imputar_valor] = cat[var_imputar_valor].fillna(valor)

# %% [markdown]
# ##### Imputar por la moda

# %% [markdown]
# ###### Variables a imputar

# %%
var_imputar_moda = ['resultado_campana_anterior','formacion']

# %% [markdown]
# ###### Funcion para imputar con la moda

# %%
def imputar_moda(variable):
    return(variable.fillna(variable.mode()[0]))

# %% [markdown]
# ###### Imputar con la moda

# %%
cat[var_imputar_moda] = cat[var_imputar_moda].apply(imputar_moda)

# %% [markdown]
# ### Atípicos

# %% [markdown]
# #### Categorías poco frecuentes

# %% [markdown]
# ##### Función para agrupar categorías raras en 'OTROS'

# %%
def agrupar_cat_raras(variable, criterio = 0.05):
    #Calcula las frecuencias
    frecuencias = variable.value_counts(normalize=True)
    #Identifica las que están por debajo del criterio
    temp = [cada for cada in frecuencias.loc[frecuencias < criterio].index.values]
    #Las recodifica en 'OTROS'
    temp2 = np.where(variable.isin(temp),'OTROS',variable)
    #Devuelve el resultado
    return(temp2)

# %% [markdown]
# ##### Variables a imputar

# %%
var_imputar_moda = ['trabajo','estado_civil']

# %% [markdown]
# ##### Aplicar

# %%
for variable in var_imputar_moda:
    cat[variable] = agrupar_cat_raras(cat[variable],criterio = 0.02)

# %% [markdown]
# ## GESTIÓN DE NUMÉRICAS

# %% [markdown]
# ### Nulos

# %% [markdown]
# #### Identificación

# %%
num.isna().sum().sort_values(ascending = False)
# Out:
# edad                            1325
# num_contactos_esta_campana         0
# num_dias_ultimo_contacto           0
# num_contactos_otras_campanas       0
# variacion_tasa_empleo              0
# euribor3m                          0
# contrata_fondos                    0
# dtype: int64

# %% [markdown]
# #### Corrección

# %% [markdown]
# ##### Eliminar la variable

# %%
num.drop(columns = 'num_contactos_otras_campanas',inplace = True)

# %% [markdown]
# ##### Eliminar registros

# %% [markdown]
# *Cuidado: Si se eliminan registros hay que eliminarlos tanto de cat como de num*

# %%
criterio = 3
cat.dropna(thresh=criterio, inplace=True)
num.dropna(thresh=criterio, inplace=True)

# %% [markdown]
# ##### Imputar por la media

# %% [markdown]
# ###### Variables a imputar

# %%
var_imputar_media = ['edad','num_contactos_esta_campana']

# %% [markdown]
# ###### Funcion para imputar con la media

# %%
def imputar_media(variable):
    if pd.api.types.is_integer_dtype(variable):
        return(variable.fillna(int(variable.mean())))
    else:
        return(variable.fillna(variable.mean()))

# %% [markdown]
# ###### Imputar con la media

# %%
#num[var_imputar_media] = num[var_imputar_media].apply(imputar_media)

# %% [markdown]
# ##### Imputar por la mediana

# %% [markdown]
# ###### Variables a imputar

# %%
var_imputar_mediana = ['edad','num_contactos_esta_campana']

# %% [markdown]
# ###### Funcion para imputar con la mediana

# %%
def imputar_mediana(variable):
    if pd.api.types.is_integer_dtype(variable):
        return(variable.fillna(int(variable.median())))
    else:
        return(variable.fillna(variable.median()))

# %% [markdown]
# ###### Imputar con la mediana

# %%
num[var_imputar_mediana] = num[var_imputar_mediana].apply(imputar_mediana)

# %% [markdown]
# ### Atípicos

# %% [markdown]
# #### Por desviación típica

# %% [markdown]
# ##### Identificación

# %% [markdown]
# ###### Definir el número de desviaciones típicas

# %%
num_desv_tip = 4

# %% [markdown]
# ###### Función que devuelve los índices de los atípicos

# %%
def atipicos_desv_tip(variable, num_desv_tip = 4):
    #sacamos los nulos por ahora
    variable = variable.dropna()
    #calculamos los límites
    media = np.mean(variable)
    sd = np.std(variable)
    umbral = sd * num_desv_tip
    lim_inf = media - umbral
    lim_sup = media + umbral
    #encontramos los índices de los que están fuera de los límites
    indices = [indice for indice,valor in variable.items() if valor < lim_inf or valor > lim_sup]
    return(indices)

# %% [markdown]
# ###### Función que cuenta el número de atípicos

# %%
def conteo_atipicos(df,variable, num_desv_tip = 4):
    atipicos = atipicos_desv_tip(df[variable], num_desv_tip)
    return(df.loc[atipicos,variable].value_counts())

# %% [markdown]
# ###### Variables a aplicar

# %%
var_atipicos_dt = ['edad','num_contactos_esta_campana']

# %% [markdown]
# ###### Aplicar

# %%
for variable in var_atipicos_dt:
    print('\n' + variable + ':\n')
    print(conteo_atipicos(num,variable,num_desv_tip))
# Out:
# edad:
#
# 88    10
# 81     7
# 85     6
# 83     5
# 82     4
# 86     3
# 84     2
# 92     2
# 91     2
# 89     1
# Name: edad, dtype: Int64
#
# num_contactos_esta_campana:
#
# 15    28
# 14    27
# 17    26
# 16    22
# 18    19
# 21    12
# 20    12
# 19    10
# 22     8
# 24     8
# 25     5
# 29     5
# 23     5
# 31     5
# 30     4
# 27     3
# 32     3
# 28     3
# 33     3
# 26     3
# 42     1
# 41     1
# 43     1
# 34     1
# Name: num_contactos_esta_campana, dtype: int64

# %% [markdown]
# ##### Corrección

# %% [markdown]
# Eliminar los registros que tengan al menos un atípico en alguna de las variables indicadas.

# %% [markdown]
# *Cuidado: Si se eliminan registros hay que eliminarlos tanto de cat como de num*

# %% [markdown]
# ###### Variables a aplicar

# %%
var_atipicos_dt = ['edad','num_contactos_esta_campana']

# %% [markdown]
# ###### Aplicar

# %%
for variable in var_atipicos_dt:
    cat.drop(atipicos_desv_tip(num[variable], num_desv_tip),axis = 0, inplace = True)
    num.drop(atipicos_desv_tip(num[variable], num_desv_tip),axis = 0, inplace = True)

# %% [markdown]
# #### Por winsorización manual para una variable

# %% [markdown]
# ##### Identificación

# %% [markdown]
# ###### Variable a analizar

# %%
variable = 'variacion_tasa_empleo'

# %% [markdown]
# ###### Comprobar el mínimo y máximo actual

# %%
num[variable].describe().loc[['min','max']]
# Out:
# min   -34.0
# max    14.0
# Name: variacion_tasa_empleo, dtype: float64

# %% [markdown]
# ##### Corrección

# %% [markdown]
# ###### Definir el mínimo y máximo tolerable.

# %%
minimo = -20
maximo = 10

# %% [markdown]
# ###### Aplicar

# %%
df[variable].clip(minimo,maximo, inplace=True)

# %% [markdown]
# #### Por winsorización automática para múltiples variables

# %% [markdown]
# ##### Variables a winsorizar.

# %%
var_winsorizar = ['edad','num_contactos_esta_campana']

# %% [markdown]
# ##### Definir los percentiles mínimos y máximos.

# %%
p_min = 0.01
p_max = 0.99

# %% [markdown]
# ##### Aplicar

# %%
for variable in var_winsorizar:
    num[variable].clip(lower = num[variable].quantile(p_min),
                       upper = num[variable].quantile(p_max),
                       inplace = True)

# %% [markdown]
# ## GUARDAR DATASETS TRAS CALIDAD DE DATOS

# %% [markdown]
# Guarda los avances en df, cat y num con un sufijo para poder guardar o recuperar avances del proyecto.
#
# En formato pickle para no perder las modificaciones de metadatos.

# %% [markdown]
# ### Definir los nombres de los archivos

# %%
ruta_trabajo = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'trabajo_resultado_calidad.pickle'
ruta_cat = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'cat_resultado_calidad.pickle'
ruta_num = ruta_proyecto + '/02_Datos/03_Trabajo/' + 'num_resultado_calidad.pickle'

# %% [markdown]
# ### Guardar los archivos

# %%
df.to_pickle(ruta_trabajo)
cat.to_pickle(ruta_cat)
num.to_pickle(ruta_num)
